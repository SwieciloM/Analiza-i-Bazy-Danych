# %% [markdown]
# # LAB2 - TIER protocol i tidy data
#
# ## Michał Święciło

# %%
import pandas as pd

# %% [markdown]
# ## Zadanie 1
#
# Celem ćwiczenia było pobranie i uporządkowanie przydzielonego zbioru danych zgodnie z protokołem TIER i zasadami "tidy data". Numer datasetu uzyskiwany był ze wzoru (N mod 5) +1, gdzie N to liczba liter w nazwisku.

# %%
# Obliczanie numeru zbioru danych
dataset_number = len('Swiecilo') % 5 + 1
print("Numer Datasetu =", dataset_number)
# Out:
# Numer Datasetu = 4

# %%
# Wczytywanie orginalnych danych
df = pd.read_csv("..\Original Data\drinks.csv")

df.head()
# print(df.to_string())
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9
