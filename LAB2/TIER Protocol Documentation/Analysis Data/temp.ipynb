# %% [markdown]
# # LAB2 - TIER protocol i tidy data
#
# ## Michał Święciło

# %%
import pandas as pd

# %%
dataset_number = len('Swiecilo') % 5 + 1
print("Numer Datasetu =", dataset_number)

ds = pd.read_csv('OriginalData/drinks.csv')

#ds.head()
# Out:
# Numer Datasetu = 4
